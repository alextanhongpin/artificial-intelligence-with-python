# %% [markdown]
# # Silhoutte Score
#
# In the real world, where data is huge is messy, you rarely will obtain data that is naturally organized into distinct clusters.
#
# Silhoutte refers to a method used to check the consistency of clusters in our data. It gives an estimate of how well each data point fits with its cluster. The silhoutte score is a metric that measures how similar a data point is to its own cluster, as compared to other clusters. The silhoutte score works with any similarity metric.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
# Load data from input file
input_file = 'data_quality.txt'
X = np.loadtxt(input_file, delimiter=',')

# Initialize variables
scores = []
values = np.arange(2, 10)

# Iterate through the defined range
for num_clusters in values:
    # Train the KMeans clustering model
    kmeans = KMeans(init='k-means++', n_clusters=num_clusters, n_init=10)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_, metric='euclidean', sample_size=len(X))
    
    print('Number of clusters = {}'.format(num_clusters))
    print('Silhoutte score = {}\n'.format(score))
    scores.append(score)

# Plot silhoutte scores
plt.figure()
plt.bar(values, scores, width=0.7, color='black', align='center')
plt.title('Silhoutte score vs number of clusters')

# Extract best score and optimal number of clusters
num_clusters = np.argmax(scores) + values[0]
print('Optimal number of clusters = {}'.format(num_clusters))

# Plot data
plt.figure()
plt.scatter(X[:, 0], X[:, 1], color='black', s=80, marker='o', facecolors='none')
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

plt.title('Input Data')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.show()
# Out:
# Number of clusters = 2
# Silhoutte score = 0.47762624870454473
#
# Number of clusters = 3
# Silhoutte score = 0.5471742411734871
#
# Number of clusters = 4
# Silhoutte score = 0.579480188968759
#
# Number of clusters = 5
# Silhoutte score = 0.5890032635647954
#
# Number of clusters = 6
# Silhoutte score = 0.6096904118954452
#
# Number of clusters = 7
# Silhoutte score = 0.5578810559195374
#
# Number of clusters = 8
# Silhoutte score = 0.48920656925931494
#
# Number of clusters = 9
# Silhoutte score = 0.4642812332638397
#
# Optimal number of clusters = 6
